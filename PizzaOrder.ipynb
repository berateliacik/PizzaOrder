# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import csv
import datetime

# %%
with open("Menu.txt", "w") as f:
    f.write("* Please Select a Pizza Base:\n")
    f.write("1: Classic\n")
    f.write("2: Margarita\n")
    f.write("3: Turkish Pizza\n")
    f.write("4: Plain Pizza\n")
    f.write("* and the sauce of your choice:\n")
    f.write("11: Olive\n")
    f.write("12: Mushrooms\n")
    f.write("13: Goat Cheese\n")
    f.write("14: Meat\n")
    f.write("15: Onion\n")
    f.write("16: Egypt\n")
    f.write("* We thank you!\n")

# %%
class Pizza:
    def __init__(self):
        self.description = "Unknown Pizza"
        self.cost = 0.0

    def get_description(self):
        return self.description

    def get_cost(self):
        return self.cost

# %%
class ClassicPizza(Pizza):
    def __init__(self):
        super().__init__()
        self.description = "Classic Pizza"
        self.cost = 10.0

class MargheritaPizza(Pizza):
    def __init__(self):
        super().__init__()
        self.description = "Margherita Pizza"
        self.cost = 12.0

class TurkishPizza(Pizza):
    def __init__(self):
        super().__init__()
        self.description = "Turkish Pizza"
        self.cost = 15.0

class PlainPizza(Pizza):
    def __init__(self):
        super().__init__()
        self.description = "Plain Pizza"
        self.cost = 17.0

# %%
class Decorator(Pizza):
    def __init__(self, component):
        self.component = component

    def get_cost(self):
        return self.component.get_cost() + Pizza.get_cost(self)

    def get_description(self):
        return self.component.get_description()

# %%
# Define the Sauce classes
class Olives(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Olives"
        self.cost = 1.0

class Mushrooms(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Mushrooms"
        self.cost = 1.0

class GoatCheese(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Goat Cheese"
        self.cost = 2.0

class Meat(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Meat"
        self.cost = 2.5

class Onions(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Onions"
        self.cost = 1.0

class Corn(Decorator):
    def __init__(self, component):
        super().__init__(component)
        self.description = "Corn"
        self.cost = 1.0

# %%
def main():
    # display menu
    with open('/content/Menu.txt', 'r') as f:
        print(f.read())

    # get pizza and sauce choices from user
    pizza_choice = int(input("Enter pizza choice (1-4): "))
    sauce_choice = int(input("Enter sauce choice (11-16): "))

    # create pizza and sauce objects
    if pizza_choice == 1:
        pizza = ClassicPizza()
    elif pizza_choice == 2:
        pizza = MargheritaPizza()
    elif pizza_choice == 3:
        pizza = TurkishPizza()
    elif pizza_choice == 4:
        pizza = PlainPizza()

    if sauce_choice == 11:
        sauce = Olives(pizza)
    elif sauce_choice == 12:
        sauce = Mushrooms(pizza)
    elif sauce_choice == 13:
        sauce = GoatCheese(pizza)
    elif sauce_choice == 14:
        sauce = Meat(pizza)
    elif sauce_choice == 15:
        sauce = Onions(pizza)
    elif sauce_choice == 16:
        sauce = Corn(pizza)

    # calculate total price
    total_price = sauce.get_cost()
    
    

    def add_order(name, tr_id, cc_number, cc_password, order_description, order_time):
      with open("/content/Orders_Database.csv", "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([name, tr_id, cc_number, cc_password, order_description, order_time])
        

    # get user's order details
    name = input("Enter your name: ")
    tr_id = input("Enter your TR ID number: ")
    cc_number = input("Enter your credit card number: ")
    cc_password = input("Enter your credit card password: ")
    order_description = sauce.get_description()
    order_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # add order to database
    add_order(name, tr_id, cc_number, cc_password, order_description, order_time)
        
    def display_orders(name, tr_id, cc_number, cc_password, order_description, order_time):
                with open('/content/Orders_Database.csv', 'r') as f:
                    reader = csv.reader(f)
                    print("All orders in database:\n")
                    print("{:<15} {:<10} {:<20} {:<20} {:<40} {:<20}".format(
                        "Name", "TR ID", "CC Number", "CC Password", "Order Description", "Order Time"))
                    print("-" * 125)
                    for row in reader:
                        print("{:<15} {:<10} {:<20} {:<20} {:<40} {:<20}".format(*row))



                # display order confirmation
                #print("Thank you for your order! Your total is:", )

                # display all orders in database
                #display_orders()

# %%
main()
# Out:
# * Please Select a Pizza Base:
# 1: Classic
# 2: Margarita
# 3: Turkish Pizza
# 4: Plain Pizza
# * and the sauce of your choice:
# 11: Olive
# 12: Mushrooms
# 13: Goat Cheese
# 14: Meat
# 15: Onion
# 16: Egypt
# * We thank you!
#
# Enter pizza choice (1-4): 3
# Enter sauce choice (11-16): 12
# Enter your name: slkjdlasd
# Enter your TR ID number: 4354
# Enter your credit card number: 354651
# Enter your credit card password: 1357435417

# %%
display_orders()
# Out:
# All orders in database:
#
# Name            TR ID      CC Number            CC Password          Order Description                        Order Time
# -----------------------------------------------------------------------------------------------------------------------------
# Berat Eliaçık   11111111111 12314345231241234    1211                 Turkish Pizza                            2023-03-13 18:36:15
# Ali Veli        3543254365436 223223543677         3433                 Turkish Pizza                            2023-03-13 18:39:58
# Ayşe Fatma      5325436435 23243243242342       22334                Turkish Pizza                            2023-03-13 18:41:05
# slkjdlasd       4354       354651               1357435417           Turkish Pizza                            2023-03-13 18:41:40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ...
